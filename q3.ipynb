# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('MessiRonaldo.csv')
df
# Out:
#      Season   Player  Liga_Goals  Liga_Asts  Liga_Aps  Liga_Mins  CL_Goals  \
# 0   2017-18    Messi          34         12        36       2996         6
# 1   2017-18  Ronaldo          26          5        27       2297        15
# 2   2016-17    Messi          37          9        34       2832        11
# 3   2016-17  Ronaldo          25          6        29       2544        12
# 4   2015-16    Messi          26         16        33       2729         6
# 5   2015-16  Ronaldo          35         11        36       3184        16
# 6   2014-15    Messi          43         21        38       3375        10
# 7   2014-15  Ronaldo          48         16        35       3096        10
# 8   2013-14    Messi          28         12        31       2498         8
# 9   2013-14  Ronaldo          31         11        30       2537        17
# 10  2012-13    Messi          46         14        32       2629         8
# ...

# %%
df.head()
# Out:
#     Season   Player  Liga_Goals  Liga_Asts  Liga_Aps  Liga_Mins  CL_Goals  \
# 0  2017-18    Messi          34         12        36       2996         6
# 1  2017-18  Ronaldo          26          5        27       2297        15
# 2  2016-17    Messi          37          9        34       2832        11
# 3  2016-17  Ronaldo          25          6        29       2544        12
# 4  2015-16    Messi          26         16        33       2729         6
#
#    CL_Asts  CL_Aps  CL_Mins
# 0        2      10      783
# 1        3      13     1170
# 2        2       9      810
# 3        5      13     1200
# 4        1       7      630

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Season      18 non-null     object
#  1   Player      18 non-null     object
#  2   Liga_Goals  18 non-null     int64
#  3   Liga_Asts   18 non-null     int64
#  4   Liga_Aps    18 non-null     int64
#  5   Liga_Mins   18 non-null     int64
#  6   CL_Goals    18 non-null     int64
#  7   CL_Asts     18 non-null     int64
#  8   CL_Aps      18 non-null     int64
#  9   CL_Mins     18 non-null     int64
# dtypes: int64(8), object(2)
# memory usage: 1.5+ KB

# %%
df1 = pd.DataFrame(df,columns=['Season','Player','Liga_Goals','Liga_Asts','Liga_Aps','Liga_Mins','CL_Goals','CL_Asts','CL_Aps','CL_Mins'])
df_of_r = df1[df1['Player']=='Ronaldo']
s = pd.Series([0,1,2,3,4,5,6,7,8])
df_of_r = df_of_r.set_index([s])
#data_of_r.drop(data_of_r['index'],inplace=True)
df_of_r
# Out:
#     Season   Player  Liga_Goals  Liga_Asts  Liga_Aps  Liga_Mins  CL_Goals  \
# 0  2017-18  Ronaldo          26          5        27       2297        15
# 1  2016-17  Ronaldo          25          6        29       2544        12
# 2  2015-16  Ronaldo          35         11        36       3184        16
# 3  2014-15  Ronaldo          48         16        35       3096        10
# 4  2013-14  Ronaldo          31         11        30       2537        17
# 5  2012-13  Ronaldo          34         11        34       2716        12
# 6  2011-12  Ronaldo          46         13        38       3353        10
# 7  2010-11  Ronaldo          40         13        34       2914         6
# 8  2009-10  Ronaldo          26         11        29       2462         7
#
#    CL_Asts  CL_Aps  CL_Mins
# 0        3      13     1170
# 1        5      13     1200
# 2        4      12     1109
# 3        4      12     1064
# 4        6      11      991
# 5        1      12     1080
# ...

# %%
df2 = pd.DataFrame(df,columns=['Season','Player','Liga_Goals','Liga_Asts','Liga_Aps','Liga_Mins','CL_Goals','CL_Asts','CL_Aps','CL_Mins'])
df_of_m = df2[df2['Player']=='Messi']
s = pd.Series([0,1,2,3,4,5,6,7,8])
df_of_m = df_of_m.set_index([s])
df_of_m
# Out:
#     Season Player  Liga_Goals  Liga_Asts  Liga_Aps  Liga_Mins  CL_Goals  \
# 0  2017-18  Messi          34         12        36       2996         6
# 1  2016-17  Messi          37          9        34       2832        11
# 2  2015-16  Messi          26         16        33       2729         6
# 3  2014-15  Messi          43         21        38       3375        10
# 4  2013-14  Messi          28         12        31       2498         8
# 5  2012-13  Messi          46         14        32       2629         8
# 6  2011-12  Messi          50         20        37       3270        14
# 7  2010-11  Messi          31         21        33       2862        12
# 8  2009-10  Messi          34         13        35       2841         8
#
#    CL_Asts  CL_Aps  CL_Mins
# 0        2      10      783
# 1        2       9      810
# 2        1       7      630
# 3        6      13     1145
# 4        1       7      630
# 5        3      11      827
# 6        9      11      990
# ...

# %%
messi_stats_LaLiga = pd.DataFrame(df_of_m,columns=['Goals_per_Game','Assists_per_Game','Minutes_per_Goal','Total_Contribution_bym','NumberOfGames'])
messi_stats_LaLiga['Goals_per_Game'] = df_of_m['Liga_Goals']/df_of_m['Liga_Aps']
messi_stats_LaLiga['Assists_per_Game'] = df_of_m['Liga_Asts']/df_of_m['Liga_Aps']
messi_stats_LaLiga['Minutes_per_Goal'] = df_of_m['Liga_Mins']/df_of_m['Liga_Goals']
messi_stats_LaLiga['Total_Contribution_bym'] = df_of_m['Liga_Goals']+df_of_m['Liga_Asts']
messi_stats_LaLiga['NumberOfGames'] = df_of_m['Liga_Aps']
messi_stats_LaLiga
# Out:
#    Goals_per_Game  Assists_per_Game  Minutes_per_Goal  Total_Contribution_bym  \
# 0        0.944444          0.333333         88.117647                      46
# 1        1.088235          0.264706         76.540541                      46
# 2        0.787879          0.484848        104.961538                      42
# 3        1.131579          0.552632         78.488372                      64
# 4        0.903226          0.387097         89.214286                      40
# 5        1.437500          0.437500         57.152174                      60
# 6        1.351351          0.540541         65.400000                      70
# 7        0.939394          0.636364         92.322581                      52
# 8        0.971429          0.371429         83.558824                      47
#
#    NumberOfGames
# 0             36
# 1             34
# 2             33
# 3             38
# 4             31
# 5             32
# 6             37
# 7             33
# 8             35

# %%
ronaldo_stats_LaLiga = pd.DataFrame(df_of_r,columns=['Goals_per_Game','Assists_per_Game','Minutes_per_Goal','Total_Contribution_byr','NumberOfGames'])
ronaldo_stats_LaLiga['Goals_per_Game'] = df_of_r['Liga_Goals']/df_of_r['Liga_Aps']
ronaldo_stats_LaLiga['Assists_per_Game'] = df_of_r['Liga_Asts']/df_of_r['Liga_Aps']
ronaldo_stats_LaLiga['Minutes_per_Goal'] = df_of_r['Liga_Mins']/df_of_r['Liga_Goals']
ronaldo_stats_LaLiga['Total_Contribution_byr'] = df_of_r['Liga_Goals']+df_of_r['Liga_Asts']
ronaldo_stats_LaLiga['NumberOfGames'] = data_of_r['Liga_Aps']
ronaldo_stats_LaLiga
# Out:
#     Goals_per_Game  Assists_per_Game  Minutes_per_Goal  \
# 1         0.962963          0.185185         88.346154
# 3         0.862069          0.206897        101.760000
# 5         0.972222          0.305556         90.971429
# 7         1.371429          0.457143         64.500000
# 9         1.033333          0.366667         81.838710
# 11        1.000000          0.323529         79.882353
# 13        1.210526          0.342105         72.891304
# 15        1.176471          0.382353         72.850000
# 17        0.896552          0.379310         94.692308
#
#     Total_Contribution_byr  NumberOfGames
# 1                       31           29.0
# 3                       31           35.0
# 5                       46           34.0
# 7                       64           34.0
# 9                       42            NaN
# 11                      45            NaN
# 13                      59            NaN
# 15                      53            NaN
# ...

# %%
messi_hist = messi_stats_LaLiga.hist(column='Total_Contribution_bym')
messi_hist
# Out:
# array([[<AxesSubplot: title={'center': 'Total_Contribution_bym'}>]],
#       dtype=object)

# %%
ronaldo_hist = ronaldo_stats_LaLiga.hist(column='Total_Contribution_byr')
ronaldo_hist
# Out:
# array([[<AxesSubplot: title={'center': 'Total_Contribution_byr'}>]],
#       dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(messi_stats_LaLiga.corr(),annot=True,fmt="1.1f")
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(15,8))
sns.heatmap(ronaldo_stats_LaLiga.corr(),annot=True,fmt = "1.1f")
# Out:
# <AxesSubplot: >
